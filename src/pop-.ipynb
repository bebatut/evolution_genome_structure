# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sc
from pathlib import Path

import prepare_data
import plot

# %%
cond = 'pop-'
cond_col = 'deepskyblue'

# %% [markdown]
# # Best individual over generations

# %%
control_seed_dfs, control_data_dfs = prepare_data.aggregate_best_ind_stats('control')
mut_seed_dfs, mut_data_dfs = prepare_data.aggregate_best_ind_stats(cond)

# %%
data_dfs = {}
for s in control_data_dfs:
    data_dfs[s] = pd.concat([control_data_dfs[s], mut_data_dfs[s]], axis=1)

# %% [markdown]
# ## Genome size

# %%
data_n = 'Genome size'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#            control        pop-
# seed01  13791.3527  18867.7540
# seed02  13343.6811  15105.5531
# seed03  13187.7014  15945.5409
# seed04  13109.4692  17085.1319
# seed05  13506.0026         NaN

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2866: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2867: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# WilcoxonResult(statistic=0.0, pvalue=0.043114446783075355)

# %% [markdown]
# ## Number of functional genes

# %%
data_n = 'Nb of functional genes'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      pop-
# seed01  132.0000  134.9110
# seed02  133.0002  132.9994
# seed03  131.0000  132.0003
# seed04  132.0001  132.0000
# seed05  132.0000       NaN

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2866: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2867: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# WilcoxonResult(statistic=3.0, pvalue=0.22491588401596185)

# %% [markdown]
# ## Mean size of the functional genes

# %%
data_n = 'Average size of functional genes'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#           control       pop-
# seed01  55.319464  54.762788
# seed02  55.272856  54.713114
# seed03  55.661448  55.047667
# seed04  56.074507  56.218152
# seed05  55.047012        NaN

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2866: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2867: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# WilcoxonResult(statistic=1.0, pvalue=0.07961580146011343)

# %% [markdown]
# ## Proportion of coding bases

# %%
data_n = 'Proportion of functional bp'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      pop-
# seed01  0.598453  0.442974
# seed02  0.622714  0.544606
# seed03  0.628126  0.517394
# seed04  0.630287  0.483812
# seed05  0.609230       NaN

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2866: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2867: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# WilcoxonResult(statistic=0.0, pvalue=0.043114446783075355)

# %% [markdown]
# ## Metabolic error

# %%
data_n = 'Metabolic error'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      pop-
# seed01  0.003719  0.003767
# seed02  0.003697  0.003745
# seed03  0.003732  0.003773
# seed04  0.003725  0.003759
# seed05  0.003733       NaN

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2866: RuntimeWarning: invalid value encountered in greater
#   r_plus = np.sum((d > 0) * r, axis=0)
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2867: RuntimeWarning: invalid value encountered in less
#   r_minus = np.sum((d < 0) * r, axis=0)
# WilcoxonResult(statistic=0.0, pvalue=0.043114446783075355)
