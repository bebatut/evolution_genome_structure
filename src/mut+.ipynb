# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sc
from pathlib import Path

import prepare_data
import plot

# %%
cond = 'mut+'
cond_col = 'red'

# %% [markdown]
# # Best individual over generations

# %%
control_seed_dfs, control_data_dfs = prepare_data.aggregate_best_ind_stats('control')
mut_seed_dfs, mut_data_dfs = prepare_data.aggregate_best_ind_stats(cond)

# %%
data_dfs = {}
for s in control_data_dfs:
    data_dfs[s] = pd.concat([control_data_dfs[s], mut_data_dfs[s]], axis=1)

# %% [markdown]
# ## Genome size

# %%
data_n = 'Genome size'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#            control        mut+
# seed01  13791.3527  14097.9990
# seed02  13343.6811  14198.1669
# seed03  13187.7014  13273.8775
# seed04  13109.4692  13914.8657
# seed05  13506.0026  13276.6070

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=2.0, pvalue=0.13801073756865956)

# %% [markdown]
# ## Number of functional genes

# %%
data_n = 'Nb of functional genes'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      mut+
# seed01  132.0000  132.0000
# seed02  133.0002  133.9989
# seed03  131.0000  134.9915
# seed04  132.0001  133.0020
# seed05  132.0000  133.1349

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)

# %% [markdown]
# ## Mean size of the functional genes

# %%
data_n = 'Average size of functional genes'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#           control       mut+
# seed01  55.319464  54.833632
# seed02  55.272856  56.001714
# seed03  55.661448  55.973450
# seed04  56.074507  56.003639
# seed05  55.047012  56.067148

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=4.0, pvalue=0.34523107177184)

# %% [markdown]
# ## Proportion of coding bases

# %%
data_n = 'Proportion of functional bp'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      mut+
# seed01  0.598453  0.586586
# seed02  0.622714  0.587754
# seed03  0.628126  0.628557
# seed04  0.630287  0.596213
# seed05  0.609230  0.631660

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=4.0, pvalue=0.34523107177184)

# %% [markdown]
# ## Metabolic error

# %%
data_n = 'Metabolic error'
df = data_dfs[data_n]
mean_values_df = prepare_data.extract_mean_values_last_gen(df, cond)
mean_values_df
# Out:
#          control      mut+
# seed01  0.003719  0.003688
# seed02  0.003697  0.003716
# seed03  0.003732  0.003726
# seed04  0.003725  0.003677
# seed05  0.003733  0.003710

# %% [markdown]
# Evolution over generation for control and condition

# %%
plot.plot_evolution_over_generation(df, data_n, ['grey']*5 + [cond_col]*5)

# %% [markdown]
# Barplot with the mean values for the last 10,000 generations

# %%
plot.plot_mean_values_barplot(mean_values_df, data_n, ['grey', cond_col])

# %% [markdown]
# Barplot with the proportion of change between control and condition

# %%
plot.plot_prop_barplot(mean_values_df, data_n, cond_col)

# %%
sc.wilcoxon(mean_values_df.iloc[:,0], mean_values_df.iloc[:,1])
# Out:
# /Users/bebatut/miniconda3/envs/aevol_scenario/lib/python3.6/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# WilcoxonResult(statistic=2.0, pvalue=0.13801073756865956)
